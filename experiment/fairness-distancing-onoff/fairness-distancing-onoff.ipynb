# %%
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

# %%
tcpClientPath = '../../../build/scratch/experiment/fairness-distancing-onoff/2024-01-17_20:19:33/tcp-flow0-client.csv'
tcpServerPath = '../../../build/scratch/experiment/fairness-distancing-onoff/2024-01-17_20:19:33/tcp-flow0-server.csv'
quicClientPath = '../../../build/scratch/experiment/fairness-distancing-onoff/2024-01-17_20:19:33/quic-flow0-client.csv'
quicServerPath = '../../../build/scratch/experiment/fairness-distancing-onoff/2024-01-17_20:19:33/quic-flow0-server.csv'


tcpClientDf = pd.read_csv(tcpClientPath)
tcpServerDf = pd.read_csv(tcpServerPath)
quicClientDf = pd.read_csv(quicClientPath)
quicServerDf = pd.read_csv(quicServerPath)

display(tcpClientDf.head())
display(tcpServerDf.head())
display(quicClientDf.head())
display(quicServerDf.head())
# Out:
#    dist     kbps          jitter  plr  pdr           delay  pkt_sent  pkt_rcv  \
# 0     1  15680.0  +1.28672e+09ns    8   91  +1.01225e+11ns      3680     3373
# 1     2  16672.8  +2.95681e+09ns    5   94  +3.23314e+11ns      7649     7218
# 2     3  18302.2  +4.86158e+09ns    2   97  +7.49748e+11ns     12244    11943
#
#    pkt_loss    source      dest
# 0       307  10.0.1.1  10.2.3.2
# 1       431  10.0.1.1  10.2.3.2
# 2       301  10.0.1.1  10.2.3.2
#    dist     kbps          jitter  plr  pdr           delay  pkt_sent  pkt_rcv  \
# 0     1  694.898  +1.21377e+09ns    0  100  +4.43944e+10ns      1687     1687
# 1     2  735.984  +2.50035e+09ns    0   99  +1.19685e+11ns      3609     3577
# 2     3  785.146  +4.00934e+09ns    3   96  +2.01584e+11ns      5972     5765
#
#    pkt_loss    source      dest
# 0         0  10.2.3.2  10.0.1.1
# 1        32  10.2.3.2  10.0.1.1
# 2       207  10.2.3.2  10.0.1.1
# ...

# %%
columns = quicClientDf.columns
data = df.values
for column in columns[1:]:
    plt.plot(data[:, 0], data[:, df.columns.get_loc(column)], label=column)
plt.xlabel('dist')
plt.ylabel('Values')
plt.legend()
plt.title('Plot of each column against dist')
plt.show()
